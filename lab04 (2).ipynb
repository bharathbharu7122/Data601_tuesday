# %% [markdown]
# # Lab

# %% [markdown]
# Using the flights dataframe answer the following questions

# %% [markdown]
# 1. When do the first and last flights leave each day?
#
# 2. When there is a missing value in `dep_time` then this is an indication of canceled flight. Find the number of cancelled flights for each (`carrier`, `origin`) combination.
#
# 3. Which carrier has the worst `dep_delay`s?
#
# 4. Which plane (`tailnum`) has the worst on-time record?
#
# 5. For each plane, count the number of flights before the first delay of greater than 1 hour.

# %%
import pandas as pd

flights = pd.read_csv('https://raw.githubusercontent.com/msaricaumbc/DS_data/master/nyc_flights.csv')

# %%
flights.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour'],
#       dtype='object')

# %%
flights
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
first_flight = flights.groupby(by= ['year', 'month', 'day']).min('dep_time')

# %%
first_flight_a = first_flight[['dep_time']]

# %%
first_flight_a1 = first_flight_df.rename(columns = {'dep_time':'firstflight'})

# %%
first_flight
# Out:
#                 dep_time  sched_dep_time  dep_delay  arr_time  sched_arr_time  \
# year month day
# 2013 1     1       517.0             515      -15.0       3.0               5
#            2        42.0             500      -13.0       1.0               5
#            3        32.0             500      -13.0       4.0               2
#            4        25.0             500      -19.0       2.0               5
#            5        14.0             500      -16.0       4.0               5
# ...                  ...             ...        ...       ...             ...
#      12    27        2.0             500      -15.0       3.0               3
#            28        7.0             500      -16.0       2.0               3
#            29        3.0             500      -13.0       3.0               3
#            30        1.0             500      -18.0       1.0               3
#            31       13.0             500      -17.0       2.0               3
#
# ...

# %%
last_flight = flights.groupby(by= ['year', 'month', 'day']).max('dep_time')

# %%
last_flight_a = last_flight[['dep_time']]

# %%
last_flight_a1 = last_flight_df.rename(columns = {'dep_time':'lastflight'})

# %%
last_flight_a1
# Out:
#                 lastflight
# year month day
# 2013 1     1        2356.0
#            2        2354.0
#            3        2349.0
#            4        2358.0
#            5        2357.0
# ...                    ...
#      12    27       2351.0
#            28       2358.0
#            29       2400.0
#            30       2356.0
#            31       2356.0
#
# [365 rows x 1 columns]

# %%
frames = [first_flight_df1, last_flight_a1]
result = pd.concat(frames, axis = 1, join = 'outer')

# %%
result
# Out:
#                 firstflight  lastflight
# year month day
# 2013 1     1          517.0      2356.0
#            2           42.0      2354.0
#            3           32.0      2349.0
#            4           25.0      2358.0
#            5           14.0      2357.0
# ...                     ...         ...
#      12    27           2.0      2351.0
#            28           7.0      2358.0
#            29           3.0      2400.0
#            30           1.0      2356.0
#            31          13.0      2356.0
#
# [365 rows x 2 columns]

# %%
a2 = flights.dep_time.isnull().groupby([flights['origin'],flights['carrier']]).sum().astype(int)

# %%
a2.Columns = ['Cancelled_flights']

# %%
a2
# Out:
# origin  carrier
# EWR     9E           68
#         AA           99
#         AS            2
#         B6           74
#         DL           39
#         EV         2164
#         MQ          168
#         OO            0
#         UA          435
#         US           75
#         VX           10
#         WN          105
# JFK     9E          807
#         AA          141
#         B6          315
#         DL          100
#         EV           82
#         HA            0
#         MQ          327
#         UA           44
#         US           26
#         VX           21
# LGA     9E          169
#         AA          396
#         B6           77
#         DL          210
#         EV          571
#         F9            3
#         FL           73
#         MQ          739
#         OO            3
#         UA          207
#         US          562
#         WN           87
#         YV           56
# Name: dep_time, dtype: int32

# %%
worst_delay = flights.groupby(by = ['carrier']). sum('dep_delay')

# %%
flight_count = flights.groupby(by = ['carrier']). count()

# %%
frame_1 = flight_count["flight"]
flight_count["flight"]
# Out:
# carrier
# 9E    18460
# AA    32729
# AS      714
# B6    54635
# DL    48110
# EV    54173
# F9      685
# FL     3260
# HA      342
# MQ    26397
# OO       32
# UA    58665
# US    20536
# VX     5162
# WN    12275
# YV      601
# Name: flight, dtype: int64

# %%
frame_2 = worst_delay['dep_delay']
worst_delay['dep_delay']
# Out:
# carrier
# 9E     291296.0
# AA     275551.0
# AS       4133.0
# B6     705417.0
# DL     442482.0
# EV    1024829.0
# F9      13787.0
# FL      59680.0
# HA       1676.0
# MQ     265521.0
# OO        365.0
# UA     701898.0
# US      75168.0
# VX      66033.0
# WN     214011.0
# YV      10353.0
# Name: dep_delay, dtype: float64

# %%
frames = [frame_1 , frame_2]
result_a = pd.concat(frames, axis =1, join = 'outer')
result_a
result_a["Ratio"] = result_a['dep_delay']/ result_a['flight']
result_a = result_a.rename({'flight': 'Flights', 'dep_delay':'Total_Delay', 'Ratio':'Ratio'}, axis = 1)
result_a.sort_values('Ratio', ascending = False)
# Out:
#          Flights  Total_Delay      Ratio
# carrier
# F9           685      13787.0  20.127007
# EV         54173    1024829.0  18.917708
# FL          3260      59680.0  18.306748
# WN         12275     214011.0  17.434705
# YV           601      10353.0  17.226290
# 9E         18460     291296.0  15.779848
# B6         54635     705417.0  12.911449
# VX          5162      66033.0  12.792135
# UA         58665     701898.0  11.964510
# OO            32        365.0  11.406250
# MQ         26397     265521.0  10.058757
# DL         48110     442482.0   9.197298
# AA         32729     275551.0   8.419170
# AS           714       4133.0   5.788515
# HA           342       1676.0   4.900585
# US         20536      75168.0   3.660304

# %%
worst_delay = flights.groupby(by = ['carrier']). sum('dep_delay')
flight_count = flights.groupby(by = ['carrier']). count()
frame_1 = flight_count["flight"]
frame_2 = worst_delay['dep_delay']
frames = [frame_1 , frame_2]
result_a = pd.concat(frames, axis =1, join = 'outer')
result_a["Ratio"] = result_a['dep_delay']/ result_a['flight']
result_a = result_a.rename({'flight': 'Flights', 'dep_delay':'Total_Delay', 'Ratio':'Ratio'}, axis = 1)
result_a.sort_values('Ratio', ascending = False)
# Out:
#          Flights  Total_Delay      Ratio
# carrier
# F9           685      13787.0  20.127007
# EV         54173    1024829.0  18.917708
# FL          3260      59680.0  18.306748
# WN         12275     214011.0  17.434705
# YV           601      10353.0  17.226290
# 9E         18460     291296.0  15.779848
# B6         54635     705417.0  12.911449
# VX          5162      66033.0  12.792135
# UA         58665     701898.0  11.964510
# OO            32        365.0  11.406250
# MQ         26397     265521.0  10.058757
# DL         48110     442482.0   9.197298
# AA         32729     275551.0   8.419170
# AS           714       4133.0   5.788515
# HA           342       1676.0   4.900585
# US         20536      75168.0   3.660304

# %%
worst_delay = flights.groupby(by = ['carrier']). sum('dep_delay')
flight_count = flights.groupby(by = ['carrier']). count()
frame_1 = flight_count["flight"]
frame_2 = worst_delay['dep_delay']
frames = [frame_1 , frame_2]
result_a = pd.concat(frames, axis =1, join = 'outer')
result_a["Ratio"] = result_a['dep_delay']/ result_a['flight']
result_a = result_a.rename({'flight': 'Flights', 'dep_delay':'Total_Delay', 'Ratio':'Ratio'}, axis = 1)
result_a.sort_values('Ratio', ascending = False)
# Out:
#          Flights  Total_Delay      Ratio
# carrier
# F9           685      13787.0  20.127007
# EV         54173    1024829.0  18.917708
# FL          3260      59680.0  18.306748
# WN         12275     214011.0  17.434705
# YV           601      10353.0  17.226290
# 9E         18460     291296.0  15.779848
# B6         54635     705417.0  12.911449
# VX          5162      66033.0  12.792135
# UA         58665     701898.0  11.964510
# OO            32        365.0  11.406250
# MQ         26397     265521.0  10.058757
# DL         48110     442482.0   9.197298
# AA         32729     275551.0   8.419170
# AS           714       4133.0   5.788515
# HA           342       1676.0   4.900585
# US         20536      75168.0   3.660304

# %%
lateplane = flights.groupby(by = ['tailnum']).sum('arr_delay')
lateplane["arr_delay"]. sort_values(ascending = False). head(1)
# Out:
# tailnum
# N15910    7317.0
# Name: arr_delay, dtype: float64

# %%
flights.groupby(by = ['year', 'month', 'day','tailnum'])
